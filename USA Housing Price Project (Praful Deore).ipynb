# %% [markdown]
# # Data Science Project: Home prices in U.S.A

# %% [markdown]
# ## Objective- To understand and model the factors influencing U.S. home prices over the last 20 years.

# %% [markdown]
# ### Data Gathering : From fred.stlouisfed.org from 2003 to 2023 year

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"]=(20,10)
import seaborn as sns

# %%
df1 = pd.read_csv(r"C:\Users\HP\Desktop\U.s house pricing\ushousing_dataset.csv")
df1.head()
# Out:
#          DATE  Year    PCI       GDP  intrest_rate  UNRATE  inflation_rate  \
# 0  01-01-2003  2003  37007  11174.13          1.25     5.9            1.84
# 1  01-04-2003  2003  36857  11312.77          1.25     6.1            1.68
# 2  01-07-2003  2003  36909  11566.67          1.02     6.1            2.02
# 3  01-10-2003  2003  37075  11772.23          1.00     5.8            2.27
# 4  01-01-2004  2004  37320  11923.45          1.00     5.7            2.32
#
#    MORTGAGE  working_age         PP       price
# 0      5.84  185863385.6  54.633333  129.321333
# 1      5.51  186640170.5  54.433333  131.756000
# 2      6.03  187303163.7  54.200000  135.013333
# 3      5.92  187948987.1  54.166667  138.834667
# 4      5.60  187874339.4  53.700000  143.299000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DATE            81 non-null     object
#  1   Year            81 non-null     int64
#  2   PCI             81 non-null     int64
#  3   GDP             81 non-null     float64
#  4   intrest_rate    81 non-null     float64
#  5   UNRATE          81 non-null     float64
#  6   inflation_rate  81 non-null     float64
#  7   MORTGAGE        81 non-null     float64
#  8   working_age     81 non-null     float64
#  9   PP              81 non-null     float64
#  10  price           81 non-null     float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 7.1+ KB

# %% [markdown]
# ## Data Exploration

# %%
df1.describe()
# Out:
#               Year           PCI           GDP  intrest_rate     UNRATE  \
# count    81.000000     81.000000     81.000000     81.000000  81.000000
# mean   2012.629630  39074.382716  17377.605802      1.340370   5.975309
# std       5.883121   1049.237456   3946.448410      1.609605   2.034424
# min    2003.000000  36857.000000  11174.130000      0.060000   3.500000
# 25%    2008.000000  38266.000000  14448.880000      0.120000   4.500000
# 50%    2013.000000  39350.000000  16648.190000      0.510000   5.400000
# 75%    2018.000000  39966.000000  20037.090000      2.080000   7.200000
# max    2023.000000  41742.000000  26813.600000      5.250000  13.000000
#
#        inflation_rate   MORTGAGE   working_age         PP       price
# count       81.000000  81.000000  8.100000e+01  81.000000   81.000000
# mean         2.076049   4.704815  2.002509e+08  43.956790  182.102638
# std          0.397010   1.114490  6.222046e+06   5.370577   43.155472
# ...

# %%
df1.isnull().sum()
# Out:
# DATE              0
# PCI               0
# GDP               0
# intrest_rate      0
# UNRATE            0
# inflation_rate    0
# MORTGAGE          0
# working_age       0
# PP                0
# price             0
# dtype: int64

# %% [markdown]
# ###  Understading the basic of  data through visualization

# %% [markdown]
# ### Univiarate Analysis

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.lineplot(x="Year",y="GDP",data=df1)
plt.show()

# %% [markdown]
# #### Overall Country's GDP has grown over the year expect the year between 2007-2008 due to recession and in the year 2020 due to pandemic                                                                                                                                                                                                                During periods of robust economic growth, individuals may feel more confident about their financial prospects, making them more likely to purchase homes

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.lineplot(x="Year",y="price",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Over the long term, many housing markets tend to experience appreciation in home values. This can be influenced by factors such as economic growth, population growth, and overall demand for housing.

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.lineplot(x="Year",y="intrest_rate",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Interest rates directly influence the cost of borrowing. When interest rates are low, mortgages become more affordable because the monthly payments are lower. This tends to stimulate demand for homes as more people can qualify for larger loans

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.lineplot(x="Year",y="inflation_rate",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Over the year we can see inflation rises and decreases , When inflation is high, central banks may raise interest rates to control it. Higher interest rates can increase the cost of borrowing for mortgages, leading to reduced demand for homes and potentially moderating housing price growth

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.lineplot(x="Year",y="UNRATE",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### The unemployment rate directly impacts individuals' income and job security. During periods of high unemployment, there is a potential reduction in household incomes, making it more challenging for individuals to afford homeownership. This can lead to decreased demand for homes and potentially lower housing prices.

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.lineplot(x="Year",y="PCI",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Per capita income is a measure of the average income per person in a specific area. Higher per capita income generally indicates greater economic prosperity. As per capita income increases, individuals may have more disposable income, potentially making homeownership more affordable. This could lead to increased demand for homes and upward pressure on housing prices.

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.lineplot(x="Year",y="MORTGAGE",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Mortgage rates directly impact the affordability of homes. When mortgage rates are low, monthly mortgage payments are more affordable, allowing potential homebuyers to qualify for larger loan amounts. This increased affordability can stimulate demand for homes and contribute to upward pressure on housing prices.

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.lineplot(x="Year",y="PP",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Purchasing power is a key factor in driving demand within the housing market. As demand increases or decreases based on changes in purchasing power, it can influence housing prices. Understanding the interplay between purchasing power and market dynamics is essential for analyzing HPI trends.

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.lineplot(x="Year",y="working_age",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Bivariate Analysis :

# %% [markdown]
# ### Understanding the Correlation between the HPI  and other factors through Correlation Heatmap

# %%
df1.corr()
# Out:
#                     Year       PCI       GDP  intrest_rate    UNRATE  \
# Year            1.000000  0.916070  0.972974     -0.304846 -0.228658
# PCI             0.916070  1.000000  0.852214     -0.315558 -0.234170
# GDP             0.972974  0.852214  1.000000     -0.161133 -0.355637
# intrest_rate   -0.304846 -0.315558 -0.161133      1.000000 -0.530280
# UNRATE         -0.228658 -0.234170 -0.355637     -0.530280  1.000000
# inflation_rate -0.209569 -0.300402 -0.092495      0.361700 -0.190280
# MORTGAGE       -0.668623 -0.717149 -0.522122      0.727467 -0.206229
# working_age     0.951427  0.936405  0.887096     -0.342437 -0.128961
# PP             -0.981460 -0.896529 -0.967428      0.273929  0.193102
# price           0.752618  0.580383  0.869085      0.192370 -0.520197
#
#                 inflation_rate  MORTGAGE  working_age        PP     price
# Year                 -0.209569 -0.668623     0.951427 -0.981460  0.752618
# ...

# %%
correlation_matrix = df1.corr()
sns.set(style="white")
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Considering Co-relation with threshold higher then  0.5 or -0.5 for insights

# %%
correlation_matrix = df1.corr()
sns.set(style="white")
threshold = 0.5
mask = abs(correlation_matrix) < threshold
correlation_matrix_masked = correlation_matrix.mask(mask)
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix_masked, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title(f'Correlation Heatmap (Threshold: {threshold})')
plt.show()

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(x="GDP",y="Year",hue="price",data=df1)
plt.xticks(rotation=90)
plt.show()
## comparison of price with gdp

# %% [markdown]
# ###### The graphs illustrate a significant positive correlation between the country's Gross Domestic Product (GDP) growth rate and the Housing Price Index (HPI) over the years. The substantial growth in the GDP reflects a robust and expanding economy, contributing to the upward trajectory of the HPI. As the GDP experiences notable increases, it acts as a key driver for the overall economic health, fostering conditions that stimulate demand in the housing market.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(x="PCI",y="Year",hue="price",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### "The compelling graphs vividly depict a strong positive correlation between the country's per capita income and the Housing Price Index (HPI) over the years. As the overall economy experiences remarkable growth, a natural consequence unfolds — a substantial increase in per capita income. This financial empowerment of individuals serves as a catalyst for a flourishing real estate market

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(x="working_age",y="Year",hue="price",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### A higher proportion of the population in the working-age range typically means a larger pool of potential homebuyers. If this demographic group experiences increased income and economic stability, it can contribute to higher demand for housing, potentially leading to an upward pressure on housing prices.

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(x="PP",y="Year",hue="price",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### The graphs clearly show that when people have less money to spend (lower purchasing power), home prices tend to go up. On the flip side, when people have more money (higher purchasing power), home prices tend to decrease. It's a straightforward connection between how much people can afford and the cost of homes, revealing the direct impact of purchasing power on housing prices

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(x="UNRATE",y="Year",hue="price",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### The graphs show a clear connection: when more people are unemployed, home prices tend to go down. On the flip side, when fewer people are unemployed, home prices tend to go up. It's like a seesaw – when unemployment goes up, prices go down, and when unemployment goes down, prices go up. This shows how job trends play a big role in shaping how much homes cost.

# %% [markdown]
# ### Other factors influencing the HPI  with  Correlation lesser then 0.5 and -0.5

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(x="inflation_rate",y="Year",hue="price",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### The graphs show that there  when prices go up in the economy (inflation increases), the prices of homes (Housing Price Index) also tend to go up. It's like they're moving together. This means that when everything gets a bit more expensive, homes follow the trend and become more expensive too. It's an interesting connection between how the cost of living and home prices are linked."

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(x="MORTGAGE",y="Year",hue="price",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### A correlation coefficient of -15 suggests a negative correlation between mortgage rates and the Housing Price Index (HPI). The negative correlation suggest that there is an inverse relationship between mortgage rates and HPI. When mortgage rates go up, there is a tendency for housing prices to go down, and when mortgage rates go down, housing prices may tend to go up.

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(x="intrest_rate",y="Year",hue="price",data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### A correlation coefficient of  15 suggests a positive correlation between interest  rates and the Housing Price Index (HPI),A positive correlation could be influenced by factors such as low-interest rates stimulating demand for homes, making them more affordable for buyers, and potentially driving up prices.

# %% [markdown]
# <font size="5">Summary:</font>
#
# The graphs reveal a robust positive correlation between the country's Gross Domestic Product (GDP) growth and the Housing Price Index (HPI) over the years. As the GDP expands, it acts as a driving force for a flourishing real estate market.
#
# Similarly, there is a compelling positive correlation between per capita income and HPI. Economic growth leads to increased per capita income, empowering individuals and fueling the real estate market.
#
# The working-age population's economic stability contributes to higher demand for housing, impacting housing prices positively. Purchasing power also plays a direct role in influencing housing prices: lower purchasing power leads to higher prices, and vice versa.
#
# Unemployment trends exhibit an inverse relationship with home prices—a rise in unemployment tends to lower housing prices, and a decrease tends to drive prices up.
#
# The connection between inflation and HPI suggests that as overall prices in the economy increase, housing prices tend to follow suit.
#
# Regarding mortgage rates, a negative correlation of -15 indicates an inverse relationship with HPI—higher mortgage rates correlate with lower housing prices.
#
# Conversely, a positive correlation of 15 between interest rates and HPI suggests that lower interest rates stimulate demand, potentially driving up housing prices.

# %% [markdown]
# ### Build a Model Now..

# %%
df1.shape
# Out:
# (81, 11)

# %%
X = df2.drop(['price','DATE'],axis='columns')
y=df2.price

# %%
y
# Out:
# 0     129.321333
# 1     131.756000
# 2     135.013333
# 3     138.834667
# 4     143.299000
#          ...
# 76    291.174000
# 77    303.019667
# 78    301.568333
# 79    298.185000
# 80    297.734667
# Name: price, Length: 81, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test)
# Out:
# 0.9219496522570864

# %% [markdown]
# ### Use K Fold cross validation to measure accuracy of our LinearRegression model

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
cross_val_score(LinearRegression(),X,y,cv=cv)
# Out:
# array([0.95926538, 0.94632828, 0.89446613, 0.94681959, 0.84414267])

# %% [markdown]
# #### As we can see with 5 iterationt he average of the given array is approximately 0.9182.

# %% [markdown]
# ### Find best model using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# ...

# %% [markdown]
# #### Based on above results we can say that decision_tree gives the best score. Hence we will use that
